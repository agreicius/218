# %%
f(x)=.25*x+40
P=point([(40,f(40)),(80,f(80)),(120,f(120)),(160,f(160))], color="blue", size=50, xmin=0, ymin=0,axes_labels=["$N$","$T$"])
l=line([(40,f(40)),(160,f(160))],color="red", thickness=2,aspect_ratio=1.75)
P+l
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(real_nth_root(x,5), (x, -40, 40)) + point((32, 2), size=30, color='red')+text("$(32,2)$", (35,2.2),color="black")
# Out:
# Graphics object consisting of 3 graphics primitives
